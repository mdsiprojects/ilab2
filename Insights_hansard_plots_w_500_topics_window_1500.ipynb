# %%
# %%
import pandas as pd
from helpers import hansard
import tqdm
# %%
experiment_folder = 'eval_num_topics_3'
root_folder = hansard.rootFolder(experiment_folder)
# %%
df_probs_fn = root_folder + '/speeches_df_topics_probs.pkl'

# %%
print(f'load df from {df_probs_fn}')
speeches_df = pd.read_pickle(df_probs_fn)
# Out:
# importing helper functions
# load df from /home/azureuser/cloudfiles/code/data/processing/hansard/experiment/eval_num_topics_3/speeches_df_topics_probs.pkl

# %%
speeches_df.head()
# Out:
#             date_time chamber parliament session period  page  \
# 0 1998-03-02 12:31:00    Reps         38       1      6     1
# 1 1998-03-02 12:32:00  Senate         38       1      6     1
# 2 1998-03-02 12:36:00    Reps         38       1      6     1
# 3 1998-03-02 12:44:00    Reps         38       1      6     1
# 4 1998-03-02 12:52:00  Senate         38       1      6     1
#
#                    name name_id party  in_gov electorate first_speech context  \
# 0  Grace, Elizabeth, MP     ML6    LP    True     Lilley            0  debate
# 1     Neal, Sen Belinda     B36   ALP    True        NSW            0  debate
# 2      Price, Roger, MP     QI4   ALP    True    Chifley            0  debate
# 3       Smith, Tony, MP     SK6    LP    True    Dickson            0  debate
# 4         Carr, Sen Kim     AW5   ALP    True        VIC            0  debate
#
#                                        context_title context_type speech_type  \
# 0                                         committees   committees      speech
# 1  social security legislation amendment (youth a...        bills      speech
# 2                                         committees   committees      speech
# 3                                         committees   committees      speech
# 4  social security legislation amendment (youth a...        bills      speech
#
#                                                probs
# 0  [9.9e-06, 1.636e-05, 9.42e-06, 1.155e-05, 9.51...
# 1  [3.83e-06, 6.33e-06, 3.65e-06, 4.47e-06, 3.68e...
# 2  [9.13e-06, 1.509e-05, 8.68e-06, 1.065e-05, 8.7...
# 3  [6.06e-06, 1.001e-05, 5.76e-06, 0.00307124, 5....
# 4  [2.69e-06, 4.45e-06, 2.56e-06, 3.14e-06, 2.58e...

# %%
#! ls -lh /home/azureuser/cloudfiles/code/data/processing/hansard/experiment/20201003_1/

# %%
speeches_df.tail(5)
# Out:
#                  date_time chamber parliament session period  page  \
# 346716 2020-09-03 17:42:00    Reps         46       1      4     0
# 346717 2020-09-03 17:45:00  Senate         46       1      4     0
# 346718 2020-09-03 17:46:00    Reps         46       1      4     0
# 346719 2020-09-03 17:50:00  Senate         46       1      4     0
# 346720 2020-09-03 17:53:00  Senate         46       1      4     0
#
#                              name name_id party  in_gov          electorate  \
# 346716      Porter, Christian, MP  208884    LP   False              Pearce
# 346717       Chandler, Sen Claire  264449    LP   False            Tasmania
# 346718            Smith, Tony, MP   00APG    LP   False               Casey
# 346719  McCarthy, Sen Malarndirri  122087   ALP   False  Northern Territory
# 346720        Waters, Sen Larissa  192970    AG   False          Queensland
#
#        first_speech context context_title context_type speech_type  \
# 346716          NaN  debate   adjournment  adjournment      speech
# 346717          NaN  debate   adjournment  adjournment      speech
# 346718          NaN  debate   adjournment  adjournment      speech
# 346719          NaN  debate   adjournment  adjournment      speech
# 346720          NaN  debate   adjournment  adjournment      speech
#
#                                                     probs
# 346716  [0.00160998, 0.00266042, 0.00153093, 0.0018776...
# 346717  [9.77e-06, 1.614e-05, 9.29e-06, 1.139e-05, 9.3...
# 346718  [0.00043119, 0.00071252, 0.00041002, 0.0005028...
# 346719  [3.345e-05, 5.527e-05, 3.181e-05, 0.01901606, ...
# 346720  [1.452e-05, 0.02662838, 1.38e-05, 1.693e-05, 1...

# %%
print('check that topics probs add up to 1 for each doc')
speeches_df.apply(lambda x: sum(x['probs']), axis='columns')
# Out:
# check that topics probs add up to 1 for each doc
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 346716    1.0
# 346717    1.0
# 346718    1.0
# 346719    1.0
# 346720    1.0
# Length: 346721, dtype: float64

# %% [markdown]
# # KLD

# %%
from scipy.stats import entropy
import numpy as np


x, y = speeches_df.probs[0], speeches_df.probs[10]
kld1 = entropy(pk=x, qk=y)
print(kld1)

# entropy 0 -> two distributions are the same
kld2 = entropy(pk=x, qk=x)
print(kld2)
# Out:
# 7.823769
# 0.0

# %% [markdown]
# # Novelty, Transcience, Resonance

# %%
Nw = 150  # window of prior speeches
Tw = 150  # window of future speeches

novelty = list()
transience = list()
resonance = list()

# %% [markdown]
# We could index our data set by data_time column, and then treat it as a timeseries for plotting and anaytics

# %%
# NOTE: is set to run sample from 300,000 to the end


for i, x in tqdm.tqdm(enumerate(speeches_df.probs[300000:]), desc='Calculate Novelty, Transience and Resonance'):
    if i < Nw:
        # there is not enough previous items
        Ni = 0 # need to decide what to set novelt for early items when no history to compare with
    else:
        klds = list()
        for d in range(Nw):
            y = speeches_df.probs[i - d]
            k = entropy(pk=y, qk=x)  # flipped the order here so the divergence calc is in chron order
            klds.append(k)
        Ni = np.mean(klds)

    novelty.append(Ni)

    if i > len(speeches_df.probs) - Tw:
        Ti = 0
    else:
        klds = list()
        for d in range(Tw):
            y = speeches_df.probs[i + d]
            k = entropy(pk=x, qk=y)
            klds.append(k)
        Ti = np.mean(klds)

    transience.append(Ti)

    Ri = Ni - Ti
    resonance.append(Ri)
# Out:
# Calculate Novelty, Transience and Resonance: 8356it [02:50, 49.20it/s]

# %%
import matplotlib.pylab as plt
plt.figure(figsize=(30,5))
plt.ylim(3,11)
plt.plot(novelty)
plt.show()

# %%
plt.figure(figsize=(30,5))
plt.ylim(3,11)
plt.plot(transience)
plt.show()

# %%
plt.figure(figsize=(30,5))
plt.ylim(-4,4)
plt.plot(resonance)
plt.show()

# %%
plt.scatter(x=novelty, y=transience)

# %%
import matplotlib.pyplot as pyplot

p = pyplot.hist2d(x=novelty, y=transience, bins=(120, 120), cmap=plt.cm.jet)
